# %%
import numpy as np
import pandas as pd
import scipy

# %%
box_scores = pd.read_csv('2022-mbb-box.csv')

# %%
box_scores.head()
# Out:
#    Unnamed: 0    game_id  season  season_type   game_date  \
# 0           1  401403407    2022            2  2022-03-13
# 1           2  401403407    2022            2  2022-03-13
# 2           3  401405907    2022            2  2022-03-13
# 3           4  401405907    2022            2  2022-03-13
# 4           5  401408162    2022            2  2022-03-13
#
#         game_date_time  team_id          team_uid            team_slug  \
# 0  2022-03-13 15:30:00     2294  s:40~l:41~t:2294        iowa-hawkeyes
# 1  2022-03-13 15:30:00     2509  s:40~l:41~t:2509  purdue-boilermakers
# 2  2022-03-13 15:15:00      235   s:40~l:41~t:235       memphis-tigers
# 3  2022-03-13 15:15:00      248   s:40~l:41~t:248      houston-cougars
# 4  2022-03-13 13:00:00      245   s:40~l:41~t:245      texas-am-aggies
#
#   team_location  ...    opponent_team_slug opponent_team_location  \
# 0          Iowa  ...   purdue-boilermakers                 Purdue
# ...

# %%
box_scores.groupby('team_id').agg(
    {
        'team_score':('team_score',np.std)
    }
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18300\2040382448.py in <module>
#       1 box_scores.groupby('team_id').agg(
#       2     {
# ----> 3         'team_score':('team_score',np.std)
#       4     }
#       5 )
#
# c:\Users\samee\OneDrive\Documents\IE 535\ie535\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#     981             return result
#
# c:\Users\samee\OneDrive\Documents\IE 535\ie535\lib\site-packages\pandas\core\apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
# ...
